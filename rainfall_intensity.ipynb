# %% [markdown]
# <a href="https://colab.research.google.com/github/KU-ZHANGZIYUE/RainfallForecasting_ConvEncDec/blob/main/rainfall_intensity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Rainfall Intensity based on Radar Data 
#Author: ZHANG Ziyue (Kyoto University)
#Date: 2011/12/6

from google.colab import drive
drive.mount('/content/drive/')
# %cd /content/drive/MyDrive/Research/30mins_4ch
# Out:
# Mounted at /content/drive/
# /content/drive/MyDrive/Research/30mins_4ch

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load('./input_30min_4ch.npy')
data = data[:,:,:,0]

# %%
intensity = np.zeros((len(data)), dtype = "float32")
for i in range(len(data)):
  single_frame = 0
  for j in range(180):
    for k in range(120):
      single_frame = single_frame + data[i,j,k]
  intensity[i] = single_frame/180/120   #spatial average

print(intensity)

# %%
plt.plot(intensity)
